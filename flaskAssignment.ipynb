# %% [markdown]
# # Flask Assignment

# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# - Flask is a built in package in python, that helps to create APIs very simply and easily
# - Tha main advantage of Flask is that it can connect between object oriented language like python and web pages like HTML

# %% [markdown]
# # Q2. Create a simple FLask application to display "Hello World!!".

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def helloWorld():
    return "<h1>Hello World!!</h1>"

if __name__=='__main__':
    app.run(host = '0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.8:5000
# Press CTRL+C to quit

# %% [markdown]
# ![image.png](attachment:70f7f09c-f484-460a-8fd4-4ed915e20041.png)

# %% [markdown]
# ### Q3. What is App Routing in Flask? Why do we use app routes?

# %% [markdown]
# - App routing is a technique using in Flask, that maps paths for different url requests.
# - App routes are used to map routes for different url requests, also used for different functions for a website

# %% [markdown]
# ### Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”route to show the following details:<br><br>Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999

# %%
@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"

@app.route("/")
def details():
    return "Company Name: ABC Corporation\nLocation: India\nContact Details: 999-999-9999"

if __name__ == '__main__':
    app.run(host = '0.0.0.0')

# %% [markdown]
# ![image.png](attachment:751ea601-ed6b-4eb2-b887-61ed49ca03d9.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# - url_for() method is used for url building
